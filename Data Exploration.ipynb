# %%
import pandas as pd
import numpy as np

# %%
train_data_raw = pd.read_csv('data/pml_train.csv')
test_data_raw = pd.read_csv('data/pml_test_features.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(train_data_raw.shape)
print(train_data_raw.columns)
train_data_raw.head()
# Out:
# (131822, 132)
# Index(['id', 'cat1', 'cat2', 'cat3', 'cat4', 'cat5', 'cat6', 'cat7', 'cat8',
#        'cat9',
#        ...
#        'cont6', 'cont7', 'cont8', 'cont9', 'cont10', 'cont11', 'cont12',
#        'cont13', 'cont14', 'loss'],
#       dtype='object', length=132)
#    id cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9   ...        cont6  \
# 0   0    A    A    A    A    B    A    A    A    A   ...     0.669748
# 1   1    B    A    A    A    A    B    A    A    A   ...     0.484775
# 2   2    A    A    A    B    A    A    A    A    A   ...     0.350956
# 3   3    B    A    A    A    A    B    A    A    A   ...     0.748243
# 4   4    A    B    A    A    A    A    A    A    B   ...     0.321058
#
#       cont7    cont8    cont9   cont10    cont11    cont12    cont13  \
# 0  0.515940  0.55421  0.53774  0.47225  0.492200  0.481306  0.756454
# 1  0.698278  0.35533  0.40657  0.40666  0.468839  0.458493  0.304350
# 2  0.363768  0.58354  0.44352  0.39599  0.341813  0.352251  0.339244
# ...

# %%
fig = plt.figure(figsize=(100, 100))

for i in range(10):
    for j in range(10):
        plt.subplot(10,10,i*10+j+1)
        index = i*10+j+1
        var = "cat" + str(index)
        train_data_raw[var].value_counts().plot(kind="bar")

# %%
fig = plt.figure(figsize=(50, 50))
for i in range(4):
    for j in range(4):
        plt.subplot(4,4,i*4+j+1)
        index = 100+i*4+j+1
        var = "cat" + str(index)
        train_data_raw[var].value_counts().plot(kind="bar")

# %%
train_data_raw[["cont1","cont2","cont3","cont4","cont5","cont6","cont7","cont8","cont9","cont10","cont11","cont12","cont13","cont14"]].hist(bins=50, figsize=(16,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000018ABE938EB8>,
# ...
#       dtype=object)

# %%
plt.figure()
train_data_raw["loss"].hist(bins=50)
plt.xlabel('id')
plt.ylabel('loss')

# %%
plt.figure()
np.log(train_data_raw["loss"]).hist(bins=50)
plt.xlabel('id')
plt.ylabel('loss')
